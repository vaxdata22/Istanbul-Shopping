# %% [markdown]
# #   Istanbul  Customer Shopping Dataset
#
# ####  Exploratory Data Analysis with Python
#
# Data Source: https://www.kaggle.com/datasets/mehmettahiraslan/customer-shopping-dataset
#
# File: customer_shopping_data.csv (7.54 MB)
#
# Dataset Provided by MEHMET TAHIR ASLAN
#
# Retrieved: 01-september-2023

# %% [markdown]
# ##   The aim of this analytics case study is dependent on:
#  * The consumers behaviour From 2021-2023
#
#  * The business performance from 2021-2023

# %% [markdown]
# ##   Outline Of The Analysis Process
#
# * Phase 1: Importing The Required python Packages
#
# * Phase 2: Acquring The Dataset
#
# * Phase 3: Data Exploration/cleaning
#
# * Phase 4: Data Minning
#
# * Phase 5: Data Visualization
#
# * Phase 6: Reporting

# %% [markdown]
# ####  Phase 1: Importing The Required python Packages

# %%
# Import required libraries/modules

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os
import warnings as wn
wn.filterwarnings('ignore')

# %% [markdown]
# ####  Phase 2: Acquiring the dataset

# %%
# Change working directory to Downloads (run only once!)

os.chdir(os.getcwd() + '\Downloads')

# %%
# Format the dataset as a dataframe

df = pd.read_csv('customer_shopping_data.csv')

df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %% [markdown]
# ####  Phase 3: Exploring The Dataset, and performing cleaning if necessary

# %%
# let's see the first five records in the dataset

df.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %%
# let's see the last five records in the dataset

df.tail()
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul

# %%
# let's view the list of field in the dataset

df.columns
# Out:
# Index(['invoice_no', 'customer_id', 'gender', 'age', 'category', 'quantity',
#        'price', 'payment_method', 'invoice_date', 'shopping_mall'],
#       dtype='object')

# %%
# let's check for the number of rows and columns in the dataset

df.shape
# Out:
# (99457, 10)

# %%
# To see the columns information

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99457 entries, 0 to 99456
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   invoice_no      99457 non-null  object
#  1   customer_id     99457 non-null  object
#  2   gender          99457 non-null  object
#  3   age             99457 non-null  int64
#  4   category        99457 non-null  object
#  5   quantity        99457 non-null  int64
#  6   price           99457 non-null  float64
#  7   payment_method  99457 non-null  object
#  8   invoice_date    99457 non-null  object
#  9   shopping_mall   99457 non-null  object
# dtypes: float64(1), int64(2), object(7)
# memory usage: 7.6+ MB

# %%
# To see the datatypes of each of the columns in the dataframe

df.dtypes
# Out:
# invoice_no         object
# customer_id        object
# gender             object
# age                 int64
# category           object
# quantity            int64
# price             float64
# payment_method     object
# invoice_date       object
# shopping_mall      object
# dtype: object

# %%
# To display all statistics for each columns in the the dataset

df.describe(include='all')
# Out:
#        invoice_no customer_id  gender           age  category      quantity  \
# count       99457       99457   99457  99457.000000     99457  99457.000000
# unique      99457       99457       2           NaN         8           NaN
# top       I138884     C241288  Female           NaN  Clothing           NaN
# freq            1           1   59482           NaN     34487           NaN
# mean          NaN         NaN     NaN     43.427089       NaN      3.003429
# std           NaN         NaN     NaN     14.990054       NaN      1.413025
# min           NaN         NaN     NaN     18.000000       NaN      1.000000
# 25%           NaN         NaN     NaN     30.000000       NaN      2.000000
# 50%           NaN         NaN     NaN     43.000000       NaN      3.000000
# 75%           NaN         NaN     NaN     56.000000       NaN      4.000000
# max           NaN         NaN     NaN     69.000000       NaN      5.000000
#
# ...

# %%
# To check for the total number of missing values in the each column of the dataframe

df.isnull().sum()
# Out:
# invoice_no        0
# customer_id       0
# gender            0
# age               0
# category          0
# quantity          0
# price             0
# payment_method    0
# invoice_date      0
# shopping_mall     0
# dtype: int64

# %%
# let's calculate the percentage of total dataset that has missing values

print((df.isnull().sum().sum() / np.product(df.shape)) * 100)
# Out:
# 0.0

# %%
# Let's rename the columns for better representation

df.columns = ['Invoice_No', 'Customer_Id', 'Gender', 'Age', 'Category', 'Quantity', 'Price', 'Payment_Method', 'Invoice_Date',
            'Shopping_Mall']

df
# Out:
#       Invoice_No Customer_Id  Gender  Age         Category  Quantity    Price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
# Let's check for unique values of the  customer id

df.Customer_Id.unique()
# Out:
# array(['C241288', 'C111565', 'C266599', ..., 'C103292', 'C800631',
#        'C273973'], dtype=object)

# %%
# The code below is used to check for the total number of unique customer id.

len(df.Customer_Id.unique())
# Out:
# 99457

# %%
# Let's check for unique values of the genders

df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# Let's check for unique values of the Age

df.Age.unique()
# Out:
# array([28, 21, 20, 66, 53, 49, 32, 69, 60, 36, 29, 67, 25, 24, 65, 42, 46,
#        23, 27, 52, 44, 51, 50, 68, 43, 59, 54, 48, 40, 41, 19, 18, 22, 61,
#        45, 64, 33, 63, 34, 47, 38, 57, 30, 26, 62, 39, 55, 56, 35, 31, 37,
#        58], dtype=int64)

# %%
# The highest & lowest age

df[['Age']].agg(['min','max'])
# Out:
#      Age
# min   18
# max   69

# %%
# the below code is used to check for the total number of unique Age.

len(df.Age.unique())
# Out:
# 52

# %%
# Let's check for unique values of the Category

df.Category.unique()
# Out:
# array(['Clothing', 'Shoes', 'Books', 'Cosmetics', 'Food & Beverage',
#        'Toys', 'Technology', 'Souvenir'], dtype=object)

# %%
# the below code is used to check for the total number of unique Category.

len(df.Category.unique())
# Out:
# 8

# %%
# Let's check for unique values of the Payment Method

df.Payment_Method.unique()
# Out:
# array(['Credit Card', 'Debit Card', 'Cash'], dtype=object)

# %%
# the below code is used to check for the total number of unique payment method.

len(df.Payment_Method.unique())
# Out:
# 3

# %%
# Let's check for unique values of the shopping mall

df.Shopping_Mall.unique()
# Out:
# array(['Kanyon', 'Forum Istanbul', 'Metrocity', 'Metropol AVM',
#        'Istinye Park', 'Mall of Istanbul', 'Emaar Square Mall',
#        'Cevahir AVM', 'Viaport Outlet', 'Zorlu Center'], dtype=object)

# %%
# the below code is used to check for the total number of unique shopping mall.

len(df.Shopping_Mall.unique())
# Out:
# 10

# %%
df.describe()
# Out:
#                 Age      Quantity         Price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# ####   Phase 4: Data Minning (Uncovering Insights)

# %% [markdown]
# Now we need to attend to the data analysis questions for more inisgts.
#
# We need to carry out some data manipulation on the following information:
#
# * which product categories generates the highest revenue for the shopping mall?
#
# * How does the gender distribution of shoppers varies across different categories?
#
# * what are the most popular products within each categories based on quantity sold?
#
# * what are the average transaction per age group?
#
# * what are the total transaction per age group
#
# * what are the most preferred payment method for each age group?
#
# * what are the most preferred payment method for each gender?
#
# * what are the specific shopping malls that attract more male or female shoppers?

# %%
##  Let's add new columns that we will be needing for our Business Analysis

df['total_sales'] = df['Quantity'] * df['Price']

df
# Out:
#       Invoice_No Customer_Id  Gender  Age         Category  Quantity    Price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
# we can use agg function to determine the maximum & mimimum sales

df.total_sales.agg(['min','max'])
# Out:
# min        5.23
# max    26250.00
# Name: total_sales, dtype: float64

# %%
# Now let's check for the statistics of our data one more time since a new column 'total sales' have been added to our dataset.

df.describe()
# Out:
#                 Age      Quantity         Price   total_sales
# count  99457.000000  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321   2528.789268
# std       14.990054      1.413025    941.184567   4222.475781
# min       18.000000      1.000000      5.230000      5.230000
# 25%       30.000000      2.000000     45.450000    136.350000
# 50%       43.000000      3.000000    203.300000    600.170000
# 75%       56.000000      4.000000   1200.320000   2700.720000
# max       69.000000      5.000000   5250.000000  26250.000000

# %%
# let's check for the  product category that generates the highest revenue from2021-2023

highest_revenue_cat = df.groupby('Category', as_index=False)[['total_sales']].sum().sort_values('total_sales', ascending=False)

highest_revenue_cat
# Out:
#           Category   total_sales
# 1         Clothing  1.139968e+08
# 4            Shoes  6.655345e+07
# 6       Technology  5.786235e+07
# 2        Cosmetics  6.792863e+06
# 7             Toys  3.980426e+06
# 3  Food & Beverage  8.495351e+05
# 0            Books  8.345529e+05
# 5         Souvenir  6.358247e+05

# %%
# How does the gender distribution of shoppers varies across different categories? 

Gender_distribution = df.groupby('Category',as_index=False)[['Gender']].value_counts()\
            .sort_values('Category',ascending=False).rename(columns={'count':'total_gender_population_per_category'})

Gender_distribution
# Out:
#            Category  Gender  total_gender_population_per_category
# 14             Toys  Female                                  6085
# 15             Toys    Male                                  4002
# 12       Technology  Female                                  2981
# 13       Technology    Male                                  2015
# 10         Souvenir  Female                                  3017
# 11         Souvenir    Male                                  1982
# 8             Shoes  Female                                  5967
# 9             Shoes    Male                                  4067
# 6   Food & Beverage  Female                                  8804
# 7   Food & Beverage    Male                                  5972
# 4         Cosmetics  Female                                  9070
# 5         Cosmetics    Male                                  6027
# 2          Clothing  Female                                 20652
# ...

# %% [markdown]
# #####  Gender Distribution Across Categories:
#
# As seen in the visualization for various categories, Female gender is leading in terms of shopping for all categories

# %%
# what are the most popular categories based on quantity sold?

cat_quantity = df.groupby('Category',as_index=False)[['Quantity']].sum().sort_values('Quantity',ascending=False)

cat_quantity
# Out:
#           Category  Quantity
# 1         Clothing    103558
# 2        Cosmetics     45465
# 3  Food & Beverage     44277
# 7             Toys     30321
# 4            Shoes     30217
# 6       Technology     15021
# 0            Books     14982
# 5         Souvenir     14871

# %%
# what are the average transaction per each age group?

Avg_transaction = df.groupby('Age', as_index=False)[['total_sales']].mean().sort_values('Age', ascending=False)

Avg_transaction
# Out:
#     Age  total_sales
# 51   69  2418.506076
# 50   68  2623.941215
# 49   67  2569.558827
# 48   66  2538.082100
# 47   65  2540.787883
# 46   64  2633.603946
# 45   63  2560.497879
# 44   62  2512.653997
# 43   61  2413.708303
# 42   60  2547.873036
# 41   59  2427.312289
# 40   58  2611.470699
# 39   57  2560.102448
# 38   56  2376.815172
# 37   55  2529.595388
# 36   54  2577.008678
# 35   53  2529.321067
# 34   52  2454.629532
# 33   51  2628.562338
# 32   50  2445.107117
# 31   49  2490.200313
# 30   48  2624.934967
# 29   47  2452.222027
# 28   46  2618.962428
# 27   45  2583.116754
# 26   44  2695.213655
# 25   43  2525.161860
# 24   42  2654.072595
# 23   41  2492.023462
# 22   40  2568.473031
# 21   39  2637.736400
# 20   38  2555.898429
# 19   37  2711.978401
# 18   36  2393.674253
# 17   35  2573.998664
# 16   34  2522.695874
# 15   33  2407.032107
# 14   32  2329.902776
# 13   31  2385.349614
# 12   30  2499.723695
# 11   29  2590.858790
# 10   28  2529.511224
# ...

# %%
 # what are the most preferred payment method for each Age?
    
age_payment = df.groupby(['Age', 'Payment_Method'], as_index=False)[['Payment_Method']].value_counts()\
        .sort_values('Payment_Method',ascending=True).rename(columns={'count':'total_payment_per_age'})

age_payment
# Out:
#      Age Payment_Method  total_payment_per_age
# 0     18           Cash                    815
# 69    41           Cash                    858
# 66    40           Cash                    901
# 132   62           Cash                    853
# 63    39           Cash                    881
# ..   ...            ...                    ...
# 68    40     Debit Card                    388
# 65    39     Debit Card                    372
# 62    38     Debit Card                    419
# 86    46     Debit Card                    372
# 155   69     Debit Card                    362
#
# [156 rows x 3 columns]

# %%
# Now let's check and see the most commonly used payment method

df['Payment_Method'].value_counts().idxmax()
# Out:
# 'Cash'

# %%
# Now let's check and be sure if cash is the most prefered payment  

prefered_payment_method = df[['Payment_Method']].value_counts()

prefered_payment_method
# Out:
# Payment_Method
# Cash              44447
# Credit Card       34931
# Debit Card        20079
# dtype: int64

# %%
# what are the most preferred payment method for each gender?
    
Gender_preferred_payment_method = df.groupby('Gender',as_index=False)[['Payment_Method']] \
                                        .value_counts().rename(columns={'count':'total_payment_per_gender'})

Gender_preferred_payment_method
# Out:
#    Gender Payment_Method  total_payment_per_gender
# 0  Female           Cash                     26509
# 1  Female    Credit Card                     21011
# 2  Female     Debit Card                     11962
# 3    Male           Cash                     17938
# 4    Male    Credit Card                     13920
# 5    Male     Debit Card                      8117

# %%
# what are the specific shopping malls that attract more male or female shoppers?

male_female_shoppers = df.groupby(['Shopping_Mall', 'Gender'], as_index=False)[['Shopping_Mall']].value_counts() \
.rename(columns={'count':'total_pop_for_male_female_shoppers'}).sort_values(['total_pop_for_male_female_shoppers'], ascending=False)

male_female_shoppers
# Out:
#         Shopping_Mall  Gender  total_pop_for_male_female_shoppers
# 8              Kanyon  Female                               11906
# 10   Mall of Istanbul  Female                               11902
# 12          Metrocity  Female                                8941
# 11   Mall of Istanbul    Male                                8041
# 9              Kanyon    Male                                7917
# 14       Metropol AVM  Female                                6144
# 13          Metrocity    Male                                6070
# 6        Istinye Park  Female                                5874
# 15       Metropol AVM    Male                                4017
# 7        Istinye Park    Male                                3907
# 4      Forum Istanbul  Female                                3016
# 18       Zorlu Center  Female                                2968
# 16     Viaport Outlet  Female                                2949
# ...

# %%
# it can be clearly seen that women are shopping more than men

shoppers_population = df.groupby('Gender',as_index=False)[['Shopping_Mall']].count().sort_values(['Shopping_Mall'], ascending=False) \
            .rename(columns={'Shopping_Mall': 'total_no_of_male_female_shoppers'})

shoppers_population
# Out:
#    Gender  total_no_of_male_female_shoppers
# 0  Female                             59482
# 1    Male                             39975

# %% [markdown]
# #### Phase 5: Data visualization

# %%
# let's visualize for the  product category that generates the highest revenue from 2021-2023?

plt.figure(figsize=(20,10))

sns.set_style("whitegrid")

sns.barplot(data=highest_revenue_cat, y='Category', x = 'total_sales')

plt.show()

# %%
#  let's visualize for the  product category that generates the highest revenue using pie 
plt.pie(x=highest_revenue_cat['total_sales'], labels=highest_revenue_cat['Category'], radius=2.5, \
                autopct = '%.2f%%', labeldistance=1.02)
plt.show()

# %%
# let's us visualize how the gender distribution of shoppers varies acrosss shopping categories from 2021-2023

plt.figure(figsize=(20,10))

sns.set_style("whitegrid")

sns.barplot(data=Gender_distribution, x='Category', y= 'total_gender_population_per_category', hue ='Gender')

plt.show()

# %%
# let's visualize for the Most popular category based on quantity sold between 2021-2023

plt.figure(figsize=(20,10))

sns.set_style("whitegrid")

sns.barplot(data=cat_quantity, y='Category', x= 'Quantity')

plt.show()

# %%
#  let's visualize for the Most popular category based on quantity sold between 2021-2023 using pie 

plt.pie(x=cat_quantity['Quantity'], labels=cat_quantity['Category'], radius=2.5, \
                autopct = '%.2f%%', labeldistance=1.02)

plt.show()

# %%
# Visualization for each age and their average sales recorded between 2021-2023

plt.figure(figsize=(20,10))

sns.set_style("whitegrid")

sns.barplot(data=Avg_transaction, x='Age', y= 'total_sales')

plt.show()

# %%
#  let's visualize the Most preferred payment Method per each age group

plt.figure(figsize=(25,10))

sns.barplot(data=age_payment, x = 'Age', y= 'total_payment_per_age', hue='Payment_Method')

plt.show()

# %%
#  let's visualize the Most preferred payment Method.

prefered_payment_method.plot(kind='pie', radius =2.5, autopct = '%.2f%%', labeldistance=1.02)

plt.show()

# %%
# let's visualize for The most preferred payment across all Gender

plt.figure(figsize=(20,10))

sns.set_style("whitegrid")

sns.barplot(data=Gender_preferred_payment_method, x='Gender', y= 'total_payment_per_gender', hue ='Payment_Method')

plt.show()

# %%
# let's visualize for male and female_shoppers across shopping malls

plt.figure(figsize=(16,8))

sns.barplot(data=male_female_shoppers, x = 'Gender', y= 'total_pop_for_male_female_shoppers', hue='Shopping_Mall')

plt.show()

# %%
# let's visualize for thr total number of Genders and how they shopped.

plt.figure(figsize=(16, 8))

sns.barplot(data=shoppers_population, x='Gender', y ='total_no_of_male_female_shoppers', palette=['red','green'])

plt.show()

# %%
# To see the visual correlation between 'Quantity' and 'price' in the shopping mall datset from 2021-2023

plt.figure(figsize=(25, 10))

sns.regplot(data=df, x='Quantity', y='Price')

plt.show()

# %%
# Checking for the correlation coefficient between the numerical fields in the shopping mall datset from 2021-2023

df.corr(method='pearson')[['total_sales']]
# Out:
#              total_sales
# Age             0.002731
# Quantity        0.461173
# Price           0.962372
# total_sales     1.000000

# %% [markdown]
# #####  A Finding From The Correlation Above Shows That There is :
#
#
# *  A postive moderate correlation between total sales and quantity and the Value = 0.461173
#
#
# *  A postive correlation between total sales and price and the Value = 0.962372

# %% [markdown]
# #### Phase 7: Report The Findings
#
#
# #####  The Dataset:
#
#
# * The Istanbul Customer Shopping Mall dataset has a moderate number of records that makes it good for analytics.The required fields were  present such as Quantity and Price, etc.
#
#
# * During cleaning there were no missing values as well as invalid entries.
#
#
# #####  Summary Of The Insights From The Data Analysis:
#
#
# * The top 5 Product Categories that generated most of the revenues are:
#
#
# 1) Clothing
#
#
# 2) Shoes
#
#
# 3) Technology
#
#
# 4) Cosmetics
#
#
# 5) Toys
#
#
#
# *  The top 5 popular categories based on quantity sold are:
#
# 1) Clothing
#
#
# 2)  Cosmetics
#
#
# 3)  Food & Beverage
#
#
# 4)  Toys
#
#
# 5)  Shoes
#
#
# ##### The  Most Preferred Payment Method is:
#
#
# * Cash(44,447%)
#
#
#
#
# #####   Detailed  information about how both genders were shopping:
#
#
# * Female = 59,482
#
#
# * Male = 39,975
#
#
#
#
#
# #####  The Answers To The Analytics Questions:
#
#
# *  It was seen that clothing categories are the top performers in terms shopping
#
#
# *  As seen from our analysis and visualizations both genders prefers to shop using cash.
#
#
# *  closely looking at our analysis we can see that Female genders are the ones shopping the most.
#
#
# *  A detailed information or a close look at our analysis and visualizations shows that most genders prefers to shopped at Kanyon shopping mall or Mall of istanbul.
#
#
# * All categories are performing well in terms of total sales and average sales as seen in our analytics and visualizations.

# %% [markdown]
# ##### Thank you for going through this case study with me.
